# %%
#pip install dexplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dexplot as dxp

# %%
daily_df = pd.read_csv("Resources/CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals (3).csv")
monthly_df = pd.read_csv("Resources/CTA_-_Ridership_-__L__Station_Entries_-_Monthly_Day-Type_Averages___Totals_2019.csv")

# %%
daily_df.head()
# Out:
#    station_id        stationname      date daytype  rides
# 0       41240     Addison-O'Hare  1/1/2014       U    928
# 1       41310            Paulina  1/1/2014       U   1140
# 2       40290       Ashland/63rd  1/1/2014       U    641
# 3       41460  Irving Park-Brown  1/1/2014       U    999
# 4       40580        54th/Cermak  1/1/2014       U    641

# %%
monthly_df.head()
# Out:
#    station_id stationame month_beginning  avg_weekday_rides  \
# 0       40900     Howard        1/1/2014             5665.7
# 1       41190     Jarvis        1/1/2014             1509.8
# 2       40100      Morse        1/1/2014             3652.2
# 3       41300     Loyola        1/1/2014             5831.0
# 4       40760  Granville        1/1/2014             3834.7
#
#    avg_saturday_rides  avg_sunday-holiday_rides  monthtotal
# 0              4130.3                    3042.2      156378
# 1              1363.0                    1025.6       43795
# 2              3075.5                    2350.6      104404
# 3              4617.3                    3299.8      163251
# 4              3228.5                    2403.2      109294

# %%
#rename the columns for the daily df
daily_df = daily_df.rename(columns={'station_id': 'Station ID',
                        'stationame': 'Station Name',
                        'date': 'Date',
                        'daytype': 'Day Type',
                        'rides': 'Rides'})

# %%
#rename the columns for the monthly df
monthly_df = monthly_df.rename(columns={'station_id': 'Station ID',
                           'stationame': 'Station Name',
                           'month_beginning': 'Month Date',
                           'avg_weekday_rides': 'Average Weekday Rides',
                           'avg_saturday_rides': 'Average Saturday Rides',
                           'avg_sunday-holiday_rides': 'Average Sunday-Holiday Rides',
                           'monthtotal': 'Monthly Total'})

# %%
monthly_df.head()
# Out:
#    Station ID Station Name Month Date  Average Weekday Rides  \
# 0       40900       Howard   1/1/2014                 5665.7
# 1       41190       Jarvis   1/1/2014                 1509.8
# 2       40100        Morse   1/1/2014                 3652.2
# 3       41300       Loyola   1/1/2014                 5831.0
# 4       40760    Granville   1/1/2014                 3834.7
#
#    Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total
# 0                  4130.3                        3042.2         156378
# 1                  1363.0                        1025.6          43795
# 2                  3075.5                        2350.6         104404
# 3                  4617.3                        3299.8         163251
# 4                  3228.5                        2403.2         109294

# %%
#january2014 = monthly_df.loc[monthly_df['Month'] == "1/1/2014"]

# %%
monthly_df['Month Date'] = pd.to_datetime(monthly_df['Month Date'])
monthly_df['Month Date']
# Out:
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
#            ...
# 12349   2021-02-01
# 12350   2021-02-01
# 12351   2021-02-01
# 12352   2021-02-01
# 12353   2021-02-01
# Name: Month Date, Length: 12354, dtype: datetime64[ns]

# %%
monthly_df['Year'] = monthly_df['Month Date'].dt.year
monthly_df['Month'] = monthly_df['Month Date'].dt.month

# %%
monthly_df.head()
# Out:
#    Station ID Station Name Month Date  Average Weekday Rides  \
# 0       40900       Howard 2014-01-01                 5665.7
# 1       41190       Jarvis 2014-01-01                 1509.8
# 2       40100        Morse 2014-01-01                 3652.2
# 3       41300       Loyola 2014-01-01                 5831.0
# 4       40760    Granville 2014-01-01                 3834.7
#
#    Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total  Year  \
# 0                  4130.3                        3042.2         156378  2014
# 1                  1363.0                        1025.6          43795  2014
# 2                  3075.5                        2350.6         104404  2014
# 3                  4617.3                        3299.8         163251  2014
# 4                  3228.5                        2403.2         109294  2014
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
lstops = pd.read_csv("Resources/CTA_-_System_Information_-_List_of__L__Stops.csv")
lstops.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
lstops = lstops.rename(columns={'MAP_ID': 'Station ID',
                                'STATION_NAME': 'Station Name',
                           'STATION_DESCRIPTIVE_NAME': 'Line Color'})
lstops.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            Station Name                         Line Color  Station ID   ADA  \
# 0                  18th                   18th (Pink Line)       40830  True
# 1                  18th                   18th (Pink Line)       40830  True
# 2           35th/Archer          35th/Archer (Orange Line)       40120  True
# 3           35th/Archer          35th/Archer (Orange Line)       40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)       41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
merge_df = pd.merge(monthly_df, lstops, on = "Station ID")
merge_df
# Out:
#        Station ID     Station Name_x Month Date  Average Weekday Rides  \
# 0           40900             Howard 2014-01-01                 5665.7
# 1           40900             Howard 2014-01-01                 5665.7
# 2           40900             Howard 2014-01-01                 5665.7
# 3           40900             Howard 2014-01-01                 5665.7
# 4           40900             Howard 2014-02-01                 6334.2
# ...           ...                ...        ...                    ...
# 25689       41700  Washington/Wabash 2020-12-01                 2313.1
# 25690       41700  Washington/Wabash 2021-01-01                 2159.1
# 25691       41700  Washington/Wabash 2021-01-01                 2159.1
# 25692       41700  Washington/Wabash 2021-02-01                 2193.9
# 25693       41700  Washington/Wabash 2021-02-01                 2193.9
#
#        Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total  \
# 0                      4130.3                        3042.2         156378
# 1                      4130.3                        3042.2         156378
# 2                      4130.3                        3042.2         156378
# 3                      4130.3                        3042.2         156378
# 4                      4197.3                        3195.5         156254
# ...                       ...                           ...            ...
# 25689                  1686.0                        1079.0          63027
# 25690                  1447.2                         928.2          55986
# 25691                  1447.2                         928.2          55986
# 25692                  1506.8                         937.8          53656
# 25693                  1506.8                         937.8          53656
#
#        Year  Month  STOP_ID  ...    RED   BLUE      G    BRN      P   Pexp  \
# 0      2014      1    30176  ...  False  False  False  False   True   True
# 1      2014      1    30173  ...   True  False  False  False  False  False
# 2      2014      1    30174  ...   True  False  False  False  False  False
# 3      2014      1    30175  ...  False  False  False  False   True   True
# 4      2014      2    30176  ...  False  False  False  False   True   True
# ...     ...    ...      ...  ...    ...    ...    ...    ...    ...    ...
# 25689  2020     12    30383  ...  False  False   True   True  False  False
# 25690  2021      1    30384  ...  False  False   True  False  False   True
# 25691  2021      1    30383  ...  False  False   True   True  False  False
# 25692  2021      2    30384  ...  False  False   True  False  False   True
# 25693  2021      2    30383  ...  False  False   True   True  False  False
#
#            Y    Pnk      O                 Location
# 0       True  False  False  (42.019063, -87.672892)
# 1      False  False  False  (42.019063, -87.672892)
# 2      False  False  False  (42.019063, -87.672892)
# 3       True  False  False  (42.019063, -87.672892)
# 4       True  False  False  (42.019063, -87.672892)
# ...      ...    ...    ...                      ...
# 25689  False  False  False   (41.88322, -87.626189)
# 25690  False   True   True   (41.88322, -87.626189)
# 25691  False  False  False   (41.88322, -87.626189)
# 25692  False   True   True   (41.88322, -87.626189)
# 25693  False  False  False   (41.88322, -87.626189)
#
# [25694 rows x 25 columns]

# %%
merge_df.columns
# Out:
# Index(['Station ID', 'Station Name_x', 'Month Date', 'Average Weekday Rides',
#        'Average Saturday Rides', 'Average Sunday-Holiday Rides',
#        'Monthly Total', 'Year', 'Month', 'STOP_ID', 'DIRECTION_ID',
#        'STOP_NAME', 'Station Name_y', 'Line Color', 'ADA', 'RED', 'BLUE', 'G',
#        'BRN', 'P', 'Pexp', 'Y', 'Pnk', 'O', 'Location'],
#       dtype='object')

# %%
new_monthly_df = merge_df.drop(columns = ['STOP_ID', 'DIRECTION_ID', 'STOP_NAME', 'Station Name_y', 'ADA', 'RED', 'BLUE', 'G', 'BRN', 'P', 'Pexp', 'Y', 'Pnk', 'O'])
new_monthly_df
# Out:
#        Station ID     Station Name_x Month Date  Average Weekday Rides  \
# 0           40900             Howard 2014-01-01                 5665.7
# 1           40900             Howard 2014-01-01                 5665.7
# 2           40900             Howard 2014-01-01                 5665.7
# 3           40900             Howard 2014-01-01                 5665.7
# 4           40900             Howard 2014-02-01                 6334.2
# ...           ...                ...        ...                    ...
# 25689       41700  Washington/Wabash 2020-12-01                 2313.1
# 25690       41700  Washington/Wabash 2021-01-01                 2159.1
# 25691       41700  Washington/Wabash 2021-01-01                 2159.1
# 25692       41700  Washington/Wabash 2021-02-01                 2193.9
# 25693       41700  Washington/Wabash 2021-02-01                 2193.9
#
#        Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total  \
# 0                      4130.3                        3042.2         156378
# 1                      4130.3                        3042.2         156378
# 2                      4130.3                        3042.2         156378
# 3                      4130.3                        3042.2         156378
# 4                      4197.3                        3195.5         156254
# ...                       ...                           ...            ...
# 25689                  1686.0                        1079.0          63027
# 25690                  1447.2                         928.2          55986
# 25691                  1447.2                         928.2          55986
# 25692                  1506.8                         937.8          53656
# 25693                  1506.8                         937.8          53656
#
#        Year  Month                                         Line Color  \
# 0      2014      1                Howard (Red, Purple & Yellow Lines)
# 1      2014      1                Howard (Red, Purple & Yellow Lines)
# 2      2014      1                Howard (Red, Purple & Yellow Lines)
# 3      2014      1                Howard (Red, Purple & Yellow Lines)
# 4      2014      2                Howard (Red, Purple & Yellow Lines)
# ...     ...    ...                                                ...
# 25689  2020     12  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25690  2021      1  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25691  2021      1  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25692  2021      2  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25693  2021      2  Washington/Wabash (Brown, Green, Orange, Purpl...
#
#                       Location
# 0      (42.019063, -87.672892)
# 1      (42.019063, -87.672892)
# 2      (42.019063, -87.672892)
# 3      (42.019063, -87.672892)
# 4      (42.019063, -87.672892)
# ...                        ...
# 25689   (41.88322, -87.626189)
# 25690   (41.88322, -87.626189)
# 25691   (41.88322, -87.626189)
# 25692   (41.88322, -87.626189)
# 25693   (41.88322, -87.626189)
#
# [25694 rows x 11 columns]

# %%
new_monthly_df [["Station Name 2", "L Color"]] = new_monthly_df["Line Color"].str.split("(",expand=True)
new_monthly_df
# Out:
#        Station ID     Station Name_x Month Date  Average Weekday Rides  \
# 0           40900             Howard 2014-01-01                 5665.7
# 1           40900             Howard 2014-01-01                 5665.7
# 2           40900             Howard 2014-01-01                 5665.7
# 3           40900             Howard 2014-01-01                 5665.7
# 4           40900             Howard 2014-02-01                 6334.2
# ...           ...                ...        ...                    ...
# 25689       41700  Washington/Wabash 2020-12-01                 2313.1
# 25690       41700  Washington/Wabash 2021-01-01                 2159.1
# 25691       41700  Washington/Wabash 2021-01-01                 2159.1
# 25692       41700  Washington/Wabash 2021-02-01                 2193.9
# 25693       41700  Washington/Wabash 2021-02-01                 2193.9
#
#        Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total  \
# 0                      4130.3                        3042.2         156378
# 1                      4130.3                        3042.2         156378
# 2                      4130.3                        3042.2         156378
# 3                      4130.3                        3042.2         156378
# 4                      4197.3                        3195.5         156254
# ...                       ...                           ...            ...
# 25689                  1686.0                        1079.0          63027
# 25690                  1447.2                         928.2          55986
# 25691                  1447.2                         928.2          55986
# 25692                  1506.8                         937.8          53656
# 25693                  1506.8                         937.8          53656
#
#        Year  Month                                         Line Color  \
# 0      2014      1                Howard (Red, Purple & Yellow Lines)
# 1      2014      1                Howard (Red, Purple & Yellow Lines)
# 2      2014      1                Howard (Red, Purple & Yellow Lines)
# 3      2014      1                Howard (Red, Purple & Yellow Lines)
# 4      2014      2                Howard (Red, Purple & Yellow Lines)
# ...     ...    ...                                                ...
# 25689  2020     12  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25690  2021      1  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25691  2021      1  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25692  2021      2  Washington/Wabash (Brown, Green, Orange, Purpl...
# 25693  2021      2  Washington/Wabash (Brown, Green, Orange, Purpl...
#
#                       Location      Station Name 2  \
# 0      (42.019063, -87.672892)             Howard
# 1      (42.019063, -87.672892)             Howard
# 2      (42.019063, -87.672892)             Howard
# 3      (42.019063, -87.672892)             Howard
# 4      (42.019063, -87.672892)             Howard
# ...                        ...                 ...
# 25689   (41.88322, -87.626189)  Washington/Wabash
# 25690   (41.88322, -87.626189)  Washington/Wabash
# 25691   (41.88322, -87.626189)  Washington/Wabash
# 25692   (41.88322, -87.626189)  Washington/Wabash
# 25693   (41.88322, -87.626189)  Washington/Wabash
#
#                                           L Color
# 0                     Red, Purple & Yellow Lines)
# 1                     Red, Purple & Yellow Lines)
# 2                     Red, Purple & Yellow Lines)
# 3                     Red, Purple & Yellow Lines)
# 4                     Red, Purple & Yellow Lines)
# ...                                           ...
# 25689  Brown, Green, Orange, Purple & Pink Lines)
# 25690  Brown, Green, Orange, Purple & Pink Lines)
# 25691  Brown, Green, Orange, Purple & Pink Lines)
# 25692  Brown, Green, Orange, Purple & Pink Lines)
# 25693  Brown, Green, Orange, Purple & Pink Lines)
#
# [25694 rows x 13 columns]

# %%
new_monthly_df = new_monthly_df.drop_duplicates()

# %%
df_2014 = new_monthly_df[new_monthly_df.Year==2014].copy()
df_2015 = new_monthly_df[new_monthly_df.Year==2015].copy()
df_2016 = new_monthly_df[new_monthly_df.Year==2016].copy()
df_2017 = new_monthly_df[new_monthly_df.Year==2017].copy()
df_2018 = new_monthly_df[new_monthly_df.Year==2018].copy()
df_2019 = new_monthly_df[new_monthly_df.Year==2019].copy()
df_2020 = new_monthly_df[new_monthly_df.Year==2020].copy()
df_2014.head()
# Out:
#     Station ID Station Name_x Month Date  Average Weekday Rides  \
# 0        40900         Howard 2014-01-01                 5665.7
# 4        40900         Howard 2014-02-01                 6334.2
# 8        40900         Howard 2014-03-01                 6336.1
# 12       40900         Howard 2014-04-01                 6281.5
# 16       40900         Howard 2014-05-01                 6336.4
#
#     Average Saturday Rides  Average Sunday-Holiday Rides  Monthly Total  Year  \
# 0                   4130.3                        3042.2         156378  2014
# 4                   4197.3                        3195.5         156254  2014
# 8                   4662.6                        3404.4         173393  2014
# 12                  4641.5                        3398.3         170351  2014
# 16                  4546.4                        3408.0         172836  2014
#
#     Month                           Line Color                 Location  \
# 0       1  Howard (Red, Purple & Yellow Lines)  (42.019063, -87.672892)
# 4       2  Howard (Red, Purple & Yellow Lines)  (42.019063, -87.672892)
# 8       3  Howard (Red, Purple & Yellow Lines)  (42.019063, -87.672892)
# 12      4  Howard (Red, Purple & Yellow Lines)  (42.019063, -87.672892)
# 16      5  Howard (Red, Purple & Yellow Lines)  (42.019063, -87.672892)
#
#    Station Name 2                      L Color
# 0         Howard   Red, Purple & Yellow Lines)
# 4         Howard   Red, Purple & Yellow Lines)
# 8         Howard   Red, Purple & Yellow Lines)
# 12        Howard   Red, Purple & Yellow Lines)
# 16        Howard   Red, Purple & Yellow Lines)

# %%
grouped2014 = df_2014.groupby('L Color')
grouped2015 = df_2015.groupby('L Color')
grouped2016 = df_2016.groupby('L Color')
grouped2017 = df_2017.groupby('L Color')
grouped2018 = df_2018.groupby('L Color')
grouped2019 = df_2019.groupby('L Color')
grouped2020 = df_2020.groupby('L Color')

# %%
sum2014 = grouped2014.sum(['Monthly Total'])
sum2015 = grouped2015.sum(['Monthly Total'])
sum2016 = grouped2016.sum(['Monthly Total'])
sum2017 = grouped2017.sum(['Monthly Total'])
sum2018 = grouped2018.sum(['Monthly Total'])
sum2019 = grouped2019.sum(['Monthly Total'])
sum2020 = grouped2020.sum(['Monthly Total'])

# %%
viz2014 = sum2014['Monthly Total']
viz2015 = sum2015['Monthly Total']
viz2016 = sum2016['Monthly Total']
viz2017 = sum2017['Monthly Total']
viz2018 = sum2018['Monthly Total']
viz2019 = sum2019['Monthly Total']
viz2020 = sum2020['Monthly Total']

# %%
df_viz = pd.concat([viz2014, viz2015, viz2016, viz2017, viz2018, viz2019, viz2020],axis=1)
df_viz.columns = ['2014','2015', '2016', '2017', '2018', '2019', '2020']
df_viz
# Out:
#                                                         2014        2015  \
# Blue Line - Forest Park Branch)                     924209.0    942126.0
# Blue Line - O'Hare Branch)                         2865335.0   2640472.0
# Blue Line)                                        42467521.0  44777160.0
# Blue, Brown, Green, Orange, Purple & Pink Lines)   5573235.0   5997069.0
# Brown & Purple Lines)                              9486710.0   9112653.0
# Brown Line)                                        9815825.0   9630048.0
# Brown, Green, Orange, Pink & Purple Lines)         5223647.0   6084048.0
# Brown, Orange, Purple & Pink Lines)                6413202.0   6328422.0
# Green & Pink Lines)                                2668533.0   2832378.0
# Green Line)                                       10432459.0  10597665.0
# Orange Line)                                       8910756.0   9077220.0
# Pink Line)                                         5452165.0   5643131.0
# Purple Line)                                       3311197.0   3322068.0
# Red & Purple Lines)                                1974643.0   1939936.0
# Red Line)                                         64391171.0  65941381.0
# Red, Brown & Purple Lines)                         8552777.0   8587086.0
# Red, Orange & Green Lines)                         7883562.0   7632034.0
# Red, Purple & Yellow Lines)                        2043714.0   2209310.0
# Yellow Line)                                        986484.0    473402.0
# Brown, Green, Orange, Purple & Pink Lines)               NaN         NaN
#
#                                                         2016      2017  \
# Blue Line - Forest Park Branch)                     914984.0    889211
# Blue Line - O'Hare Branch)                         2533597.0   2494196
# Blue Line)                                        44420907.0  43453621
# Blue, Brown, Green, Orange, Purple & Pink Lines)   5972666.0   6022533
# Brown & Purple Lines)                              9496271.0   9368371
# Brown Line)                                        9886207.0   9709753
# Brown, Green, Orange, Pink & Purple Lines)         5955181.0   5879773
# Brown, Orange, Purple & Pink Lines)                6545065.0   6407033
# Green & Pink Lines)                                2837556.0   2844470
# Green Line)                                        9722540.0   9358562
# Orange Line)                                       9016657.0   8774837
# Pink Line)                                         5267199.0   5044294
# Purple Line)                                       3275669.0   3185926
# Red & Purple Lines)                                1871848.0   1788035
# Red Line)                                         64965722.0  61094912
# Red, Brown & Purple Lines)                         8393015.0   7840616
# Red, Orange & Green Lines)                         7612694.0   7471644
# Red, Purple & Yellow Lines)                        1905107.0   1844872
# Yellow Line)                                        884760.0    912483
# Brown, Green, Orange, Purple & Pink Lines)               NaN   1016989
#
#                                                       2018      2019      2020
# Blue Line - Forest Park Branch)                     873289    838646    357808
# Blue Line - O'Hare Branch)                         2526333   2494304    822720
# Blue Line)                                        42917824  41777714  14044781
# Blue, Brown, Green, Orange, Purple & Pink Lines)   6048315   5830767   1648674
# Brown & Purple Lines)                              9443693   9185230   2802577
# Brown Line)                                        9533495   9340841   3094301
# Brown, Green, Orange, Pink & Purple Lines)         6004805   5870670   1800717
# Brown, Orange, Purple & Pink Lines)                6284219   6309948   1898658
# Green & Pink Lines)                                3038317   3122020   1089998
# Green Line)                                        9185680   8629857   3896534
# Orange Line)                                       8462263   8182401   3153749
# Pink Line)                                         4938107   4801625   2207473
# Purple Line)                                       3126507   3010072   1063947
# Red & Purple Lines)                                2061761   2043387    857136
# Red Line)                                         58526858  55614220  19691201
# Red, Brown & Purple Lines)                         7564841   7464709   2403602
# Red, Orange & Green Lines)                         7109934   6933820   2627850
# Red, Purple & Yellow Lines)                        1743680   1650809    762300
# Yellow Line)                                        884533    832293    284215
# Brown, Green, Orange, Purple & Pink Lines)         3178881   3126070   1082287

# %%
df_viz.plot.bar(figsize=(30,20), fontsize=20, width=.8)
plt.title('L Ridership by Year', fontsize=30)
plt.ylabel('Total Ridership in Millions', fontsize=20)
plt.legend(fontsize='xx-large', prop={'size': 30})
plt.grid(axis='y', alpha=.5, linewidth=1.5)
plt.savefig('L Ridership by Year.png')

# %%
df_viz.reset_index(inplace=True)
df_viz
# Out:
#                                                index        2014        2015  \
# 0                    Blue Line - Forest Park Branch)    924209.0    942126.0
# 1                         Blue Line - O'Hare Branch)   2865335.0   2640472.0
# 2                                         Blue Line)  42467521.0  44777160.0
# 3   Blue, Brown, Green, Orange, Purple & Pink Lines)   5573235.0   5997069.0
# 4                              Brown & Purple Lines)   9486710.0   9112653.0
# 5                                        Brown Line)   9815825.0   9630048.0
# 6         Brown, Green, Orange, Pink & Purple Lines)   5223647.0   6084048.0
# 7                Brown, Orange, Purple & Pink Lines)   6413202.0   6328422.0
# 8                                Green & Pink Lines)   2668533.0   2832378.0
# 9                                        Green Line)  10432459.0  10597665.0
# 10                                      Orange Line)   8910756.0   9077220.0
# 11                                        Pink Line)   5452165.0   5643131.0
# 12                                      Purple Line)   3311197.0   3322068.0
# 13                               Red & Purple Lines)   1974643.0   1939936.0
# 14                                         Red Line)  64391171.0  65941381.0
# 15                        Red, Brown & Purple Lines)   8552777.0   8587086.0
# 16                        Red, Orange & Green Lines)   7883562.0   7632034.0
# 17                       Red, Purple & Yellow Lines)   2043714.0   2209310.0
# 18                                      Yellow Line)    986484.0    473402.0
# 19        Brown, Green, Orange, Purple & Pink Lines)         NaN         NaN
#
#           2016      2017      2018      2019      2020
# 0     914984.0    889211    873289    838646    357808
# 1    2533597.0   2494196   2526333   2494304    822720
# 2   44420907.0  43453621  42917824  41777714  14044781
# 3    5972666.0   6022533   6048315   5830767   1648674
# 4    9496271.0   9368371   9443693   9185230   2802577
# 5    9886207.0   9709753   9533495   9340841   3094301
# 6    5955181.0   5879773   6004805   5870670   1800717
# 7    6545065.0   6407033   6284219   6309948   1898658
# 8    2837556.0   2844470   3038317   3122020   1089998
# 9    9722540.0   9358562   9185680   8629857   3896534
# 10   9016657.0   8774837   8462263   8182401   3153749
# 11   5267199.0   5044294   4938107   4801625   2207473
# 12   3275669.0   3185926   3126507   3010072   1063947
# 13   1871848.0   1788035   2061761   2043387    857136
# 14  64965722.0  61094912  58526858  55614220  19691201
# 15   8393015.0   7840616   7564841   7464709   2403602
# 16   7612694.0   7471644   7109934   6933820   2627850
# 17   1905107.0   1844872   1743680   1650809    762300
# 18    884760.0    912483    884533    832293    284215
# 19         NaN   1016989   3178881   3126070   1082287

# %%
df_viz.rename(columns={"index": "L Color"}, inplace=True)
df_viz
# Out:
#                                              L Color        2014        2015  \
# 0                    Blue Line - Forest Park Branch)    924209.0    942126.0
# 1                         Blue Line - O'Hare Branch)   2865335.0   2640472.0
# 2                                         Blue Line)  42467521.0  44777160.0
# 3   Blue, Brown, Green, Orange, Purple & Pink Lines)   5573235.0   5997069.0
# 4                              Brown & Purple Lines)   9486710.0   9112653.0
# 5                                        Brown Line)   9815825.0   9630048.0
# 6         Brown, Green, Orange, Pink & Purple Lines)   5223647.0   6084048.0
# 7                Brown, Orange, Purple & Pink Lines)   6413202.0   6328422.0
# 8                                Green & Pink Lines)   2668533.0   2832378.0
# 9                                        Green Line)  10432459.0  10597665.0
# 10                                      Orange Line)   8910756.0   9077220.0
# 11                                        Pink Line)   5452165.0   5643131.0
# 12                                      Purple Line)   3311197.0   3322068.0
# 13                               Red & Purple Lines)   1974643.0   1939936.0
# 14                                         Red Line)  64391171.0  65941381.0
# 15                        Red, Brown & Purple Lines)   8552777.0   8587086.0
# 16                        Red, Orange & Green Lines)   7883562.0   7632034.0
# 17                       Red, Purple & Yellow Lines)   2043714.0   2209310.0
# 18                                      Yellow Line)    986484.0    473402.0
# 19        Brown, Green, Orange, Purple & Pink Lines)         NaN         NaN
#
#           2016      2017      2018      2019      2020
# 0     914984.0    889211    873289    838646    357808
# 1    2533597.0   2494196   2526333   2494304    822720
# 2   44420907.0  43453621  42917824  41777714  14044781
# 3    5972666.0   6022533   6048315   5830767   1648674
# 4    9496271.0   9368371   9443693   9185230   2802577
# 5    9886207.0   9709753   9533495   9340841   3094301
# 6    5955181.0   5879773   6004805   5870670   1800717
# 7    6545065.0   6407033   6284219   6309948   1898658
# 8    2837556.0   2844470   3038317   3122020   1089998
# 9    9722540.0   9358562   9185680   8629857   3896534
# 10   9016657.0   8774837   8462263   8182401   3153749
# 11   5267199.0   5044294   4938107   4801625   2207473
# 12   3275669.0   3185926   3126507   3010072   1063947
# 13   1871848.0   1788035   2061761   2043387    857136
# 14  64965722.0  61094912  58526858  55614220  19691201
# 15   8393015.0   7840616   7564841   7464709   2403602
# 16   7612694.0   7471644   7109934   6933820   2627850
# 17   1905107.0   1844872   1743680   1650809    762300
# 18    884760.0    912483    884533    832293    284215
# 19         NaN   1016989   3178881   3126070   1082287

# %%
df_viz["L Color"] = df_viz["L Color"].str.replace("Lines", "",regex = True)
df_viz.head()
# Out:
#                                        L Color        2014        2015  \
# 0              Blue Line - Forest Park Branch)    924209.0    942126.0
# 1                   Blue Line - O'Hare Branch)   2865335.0   2640472.0
# 2                                   Blue Line)  42467521.0  44777160.0
# 3  Blue, Brown, Green, Orange, Purple & Pink )   5573235.0   5997069.0
# 4                             Brown & Purple )   9486710.0   9112653.0
#
#          2016      2017      2018      2019      2020
# 0    914984.0    889211    873289    838646    357808
# 1   2533597.0   2494196   2526333   2494304    822720
# 2  44420907.0  43453621  42917824  41777714  14044781
# 3   5972666.0   6022533   6048315   5830767   1648674
# 4   9496271.0   9368371   9443693   9185230   2802577

# %%
df_viz["L Color"] = df_viz["L Color"].str.replace("Line", "",regex = True)
df_viz.head()
# Out:
#                                        L Color        2014        2015  \
# 0                  Blue  - Forest Park Branch)    924209.0    942126.0
# 1                       Blue  - O'Hare Branch)   2865335.0   2640472.0
# 2                                       Blue )  42467521.0  44777160.0
# 3  Blue, Brown, Green, Orange, Purple & Pink )   5573235.0   5997069.0
# 4                             Brown & Purple )   9486710.0   9112653.0
#
#          2016      2017      2018      2019      2020
# 0    914984.0    889211    873289    838646    357808
# 1   2533597.0   2494196   2526333   2494304    822720
# 2  44420907.0  43453621  42917824  41777714  14044781
# 3   5972666.0   6022533   6048315   5830767   1648674
# 4   9496271.0   9368371   9443693   9185230   2802577

# %%
df_viz["L Color"] = df_viz["L Color"].str.replace(")", "",regex = True)
df_viz.head()
# Out:
#                                       L Color        2014        2015  \
# 0                  Blue  - Forest Park Branch    924209.0    942126.0
# 1                       Blue  - O'Hare Branch   2865335.0   2640472.0
# 2                                       Blue   42467521.0  44777160.0
# 3  Blue, Brown, Green, Orange, Purple & Pink    5573235.0   5997069.0
# 4                             Brown & Purple    9486710.0   9112653.0
#
#          2016      2017      2018      2019      2020
# 0    914984.0    889211    873289    838646    357808
# 1   2533597.0   2494196   2526333   2494304    822720
# 2  44420907.0  43453621  42917824  41777714  14044781
# 3   5972666.0   6022533   6048315   5830767   1648674
# 4   9496271.0   9368371   9443693   9185230   2802577

# %%
df_viz.plot.bar(x='L Color', figsize=(30,20), fontsize=20, width=.8)
plt.xticks(ha='right', rotation=45)
plt.title('L Ridership by Line Color by Year', fontsize=30)
plt.ylabel('Total Ridership in Millions', fontsize=20)
plt.xlabel('L Color', fontsize=20)
plt.legend(fontsize='xx-large', prop={'size': 30})
plt.grid(axis='y', alpha=.5, linewidth=1.5)
plt.savefig('L Ridership by Line Color by Year.png')
